# %% [markdown]
# # Intro to Code

# %%
print("hello world")
# Out:
# hello world

# %%
x=0
while(x < 10):
    print("wow")
    x=x+1
# Out:
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
